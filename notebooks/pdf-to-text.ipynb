# %%
import os
from pypdf import PdfReader
import pandas as pd

# %%
folder_path = '../data/pdf'

# %%
from pdfminer.high_level import extract_text as pdfminer_extract_text

pdfs = [f for f in os.listdir(folder_path) if f.endswith('.pdf')]

texts = []
for pdf in pdfs:
    file_path = os.path.join(folder_path, pdf)
    reader = PdfReader(file_path)
    for idx in range(len(reader.pages)):
        page_text = pdfminer_extract_text(file_path, page_numbers=[idx])
        page_text = '\n'.join(unsplit_spaced_words(l) for l in page_text.split('\n'))
        texts.append(
            {
                'document': pdf,
                'page': idx + 1,
                'text': page_text,
            }
        )

df = pd.DataFrame(texts)
df
# Out:
#             document  page                                               text
# 0   SaltLakeCity.pdf     1  ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# 1   SaltLakeCity.pdf     2  stereotypes. Users must edit or disregard bias...
# 2      Cambridge.pdf     1  City of Cambridge Guidelines on Using Generati...
# 3      Cambridge.pdf     2  Only use City-approved, authorized AI tools fo...
# 4      Cambridge.pdf     3  •  Recommended Practice: To improve team learn...
# 5      Cambridge.pdf     4  o  Copilot Chat, a Microsoft Generative AI cha...
# 6      Cambridge.pdf     5  •  City of Cambridge Written Information Secur...
# 7      Cambridge.pdf     6  o  Test results, diagnoses, or treatment detai...
# 8      Cambridge.pdf     7  used in limited non-sensitive, low-risk \ncirc...
# 9      LongBeach.pdf     1  Generative AI Guidance \n\nV 1.3 \n\nIntroduct...
# 10     LongBeach.pdf     2  City of Long Beach Generative AI Guidance v1.3...
# 11     LongBeach.pdf     3  City of Long Beach Generative AI Guidance v1.3...
# 12     LongBeach.pdf     4  City of Long Beach Generative AI Guidance v1.3...
# 13     LongBeach.pdf     5  City of Long Beach Generative AI Guidance v1.3...
# 14     LongBeach.pdf     6  City of Long Beach Generative AI Guidance v1.3...
# 15     LongBeach.pdf     7  City of Long Beach Generative AI Guidance v1.3...
# 16     LongBeach.pdf     8  City of Long Beach Generative AI Guidance v1.3...
# 17     LongBeach.pdf     9  City of Long Beach Generative AI Guidance v1.3...
# 18     LongBeach.pdf    10  City of Long Beach Generative AI Guidance v1.3...
# 19       SanJose.pdf     1  City of San José \nArtificial Intelligence (AI...
# 20       SanJose.pdf     2  City of San José \nArtificial Intelligence (AI...
# 21       SanJose.pdf     3  City of San José \nArtificial Intelligence (AI...
# 22       SanJose.pdf     4  City of San José \nArtificial Intelligence (AI...
# 23            SF.pdf     1  San Francisco Generative AI Guidelines (2025) ...
# 24            SF.pdf     2  1.1. Purpose of the Guidelines \n\nThese guide...
# 25            SF.pdf     3  As a general rule, City employees must always ...
# 26            SF.pdf     4  For these use-cases, AI can serve as a support...
# 27            SF.pdf     5  Example: Quoting AI-Generated Text \n\nWhen as...
# 28            SF.pdf     6  o  Charter Section 16.130, Privacy First Polic...
# 29            SF.pdf     7  o  Notifying DT of any updates if GenAI tools ...
# 30            SF.pdf     8  5. Background \n\n5.1. Current Legislative and...
# 31            SF.pdf     9  This report includes content drafted with supp...
# 32            SF.pdf    10  political and other biases. Since the models h...
# 33            DC.pdf     1  District of Columbia Government – Office of th...
# 34            DC.pdf     2  4.1.7. \n\nPrior to using any AI and ML platfo...
# 35            DC.pdf     3  6.  Definitions \n\nThe definition of the term...
# 36            DC.pdf     4  APPENDIX \n\nAppendix 1 – Terms and Definition...
# 37         Tempe.pdf     1  Ethical Artificial Intelligence (AI) Policy\n\...
# 38         Tempe.pdf     2  steps to prevent discrimination, protect priva...
# 39         Tempe.pdf     3  IV.\n\nAI Governance\n\n1. Departments shall\n...
# 40        Boston.pdf     1  City of Boston Interim Guidelines\nfor Using G...
# 41        Boston.pdf     2  Sample Use Cases\n\nThese are some of the type...
# 42        Boston.pdf     3  get the beneﬁts from the tools while avoiding ...
# 43        Boston.pdf     4  Guidelines\n\nFact Check and review all conten...
# 44        Boston.pdf     5  AI, contact DoIT so we can help you provision ...
# 45        Boston.pdf     6  3. Do not use generative AI to create communic...
# 46        Boston.pdf     7  Do’s:\n\n1. Try different languages. ChatGPT, ...
# 47        Boston.pdf     8  3. Be aware that the resulting summary might h...
# 48        Boston.pdf     9  ● Example: make an image in a medieval style o...
# 49        Boston.pdf    10  discuss important questions about the impact o...
# 50       Lebanon.pdf     1  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 51       Lebanon.pdf     2  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 52       Lebanon.pdf     3  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 53       Lebanon.pdf     4  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 54       Lebanon.pdf     5  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 55       Lebanon.pdf     6  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 56       Lebanon.pdf     7  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...

# %%
import re, unicodedata

UNICODE_FIXES = {
    '\u00AD': '',   # soft hyphen
    '\u2010': '-', '\u2011': '-', '\u2012': '-', '\u2013': '-', '\u2014': '-', '\u2212': '-',
    '\u2022': ' ', '\u25CF': ' ', '\u25AA': ' ', '\u2027': ' ', '\u00B7': ' ',
    '\ufb01': 'fi', '\ufb02': 'fl',
}
def normalize_unicode(s: str) -> str:
    s = unicodedata.normalize('NFKC', s)
    for k, v in UNICODE_FIXES.items():
        s = s.replace(k, v)
    return s

SPACED_LETTERS_RX = re.compile(r'\b(?:[A-Za-z]\s){3,}[A-Za-z]\b')
def unsplit_spaced_words(line: str) -> str:
    def _join(m: re.Match) -> str:
        return m.group(0).replace(' ', '')
    prev = None
    while prev != line:
        prev = line
        line = SPACED_LETTERS_RX.sub(_join, line)
    return line

# --- NEW: split CamelCase & alnum boundaries BEFORE lowercasing ---
CAMEL_RX = re.compile(r'([a-z])([A-Z])')
ALNUM_RX_1 = re.compile(r'([A-Za-z])(\d)')
ALNUM_RX_2 = re.compile(r'(\d)([A-Za-z])')

def split_word_boundaries(line: str) -> str:
    # Split lower→Upper (InterimGuidelines -> Interim Guidelines)
    line = CAMEL_RX.sub(r'\1 \2', line)
    # Split letter→digit and digit→letter (rare, but safe)
    line = ALNUM_RX_1.sub(r'\1 \2', line)
    line = ALNUM_RX_2.sub(r'\1 \2', line)
    return line

# --- Your header patterns (unchanged, with Boston additions) ---
HEADER_PATTERNS = [
    r'City of Cambridge Guidelines on Using Generative Artificial Intelligence.*',
    r'City of Cambridge Guidelines.*',
    r'San Francisco Generative AI Guidelines.*',
    r'ARTICLE\s+E\..*',
    r'Use of Generative Artificial Intelligence.*',
    r'City of San Jos\u00e9 City Administrative Policy Manual Artificial Intelligence.*',
    r'City of San Jos\u00e9 .* Artificial Intelligence.*',
    r'Artificial Intelligence \(AI\) Policy.*',
    r'Ethical Artificial Intelligence \(AI\) Policy.*',
    r'AI/ML Governance Policy.*',
    r'District of Columbia Government.*Office of the Chief Technology Officer.*',
    r'Acceptable Use Policy Page\s*\d+\s*of\s*\d+.*',
    r'City of Lebanon New Hampshire.*ADMINISTRATIVE POLICIES.*Use of Artificial Intelligence.*',
    r'Use of Artificial Intelligence.*ADM.*',
    r'City of Boston Interim.*Guidelines.*for Using Generative AI.*',
    r'Unset\s*',
    r'Sample\s*Use\s*Cases\s*',
    r'City of Long Beach Generative AI Guidance.*',
    r'City of San Jos\u00e9.*',
    r'City Administrative Policy Manual.*',
    r'ADMINISTRATIVE POLICIES\s*&\s*PROCEDURES\s+Use of Artificial Intelligence\s+City of Lebanon\s+New Hampshire.*',
    r'ADMINISTRATIVE POLICIES\s*&\s*PROCEDURES.*Use of Artificial Intelligence.*City of Lebanon.*New Hampshire.*Policy Number.*Effective Date.*Last Revision.*Page No\..*ADM\s*-\s*\d+.*Approved by:.*',
]
HEADER_RX = re.compile(r'^\s*(?:' + '|'.join(HEADER_PATTERNS) + r')$', flags=re.I | re.M)
PAGE_RX   = re.compile(r'^\s*Page\s+\d+\s*$', flags=re.I | re.M)
URL_MAIL  = re.compile(r'https?://\S+|\S+@\S+', flags=re.I)
TOC_RX    = re.compile(r'\btable of contents\b.*', flags=re.I | re.S)
# Remove Lebanon policy metadata fragments
POLICY_META_RX = re.compile(r'\b(?:policy\s+number|effective\s+date|last\s+revision|page\s+no\.?|adm\s*-?\s*\d+|approved\s+by:?)\b.*', flags=re.I)

def clean_text(t) -> str:
    if t is None:
        t = ""
    t = str(t)

    # 1) Unicode normalization (ligatures, bullets, soft hyphens)
    t = normalize_unicode(t)

    # 2) Normalize newlines and preserve paragraph breaks
    t = re.sub(r'\r\n', '\n', t)
    t = re.sub(r'\n\n+', '\n\n', t)  # collapse 3+ newlines to double (paragraph break)
    
    # 3) Join spaced-out letters (Boston PDFs) - process per paragraph
    paragraphs = t.split('\n\n')
    paragraphs = [unsplit_spaced_words(para) for para in paragraphs]
    t = '\n\n'.join(paragraphs)

    # 4) Split CamelCase/alnum boundaries (BEFORE lowercasing) - per paragraph
    paragraphs = t.split('\n\n')
    paragraphs = [split_word_boundaries(para) for para in paragraphs]
    t = '\n\n'.join(paragraphs)

    # 5) Remove known headers/banners
    t = HEADER_RX.sub(' ', t)

    # 6) Remove page footers like "Page 1"
    t = PAGE_RX.sub(' ', t)

    # 7) Strip URLs and emails
    t = URL_MAIL.sub(' ', t)

    # 8) Drop "Table of Contents" blocks if extracted
    t = TOC_RX.sub(' ', t)

    # 9) Remove policy metadata fragments
    t = POLICY_META_RX.sub(' ', t)

    # 10) Keep letters and space only; lowercase (removes all digits, hyphens, etc.)
    t = re.sub(r'[^a-zA-Z\s]', ' ', t.lower())

    # 11) Remove Roman numerals (i, ii, iii, iv, v, vi, vii, viii, ix, x, etc.)
    t = re.sub(r'\b(?:i{1,3}|i?[vx]|vi{0,3}|i{1,3}[vx])\b', ' ', t)

    # 12) Remove standalone single letters and any remaining digit sequences
    t = re.sub(r'\b[a-z]\b', ' ', t)
    t = re.sub(r'\b\d+\b', ' ', t)  # catch any digit sequences that survived

    # 13) Collapse whitespace within paragraphs, preserve \n\n breaks
    paragraphs = t.split('\n\n')
    # Within each paragraph: collapse any newlines/spaces to single space
    paragraphs = [re.sub(r'\s+', ' ', para).strip() for para in paragraphs]
    # Remove empty paragraphs
    paragraphs = [p for p in paragraphs if p]
    return '\n\n'.join(paragraphs)

# %%
df['cleaned_text'] = (
    df['text']
    .fillna('')         # guard against None/NaN
    .astype(str)        # ensure strings
    .map(clean_text)    # apply the cleaner
)

df
# Out:
#             document  page                                               text  \
# 0   SaltLakeCity.pdf     1  ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# 1   SaltLakeCity.pdf     2  stereotypes. Users must edit or disregard bias...
# 2      Cambridge.pdf     1  City of Cambridge Guidelines on Using Generati...
# 3      Cambridge.pdf     2  Only use City-approved, authorized AI tools fo...
# 4      Cambridge.pdf     3  •  Recommended Practice: To improve team learn...
# 5      Cambridge.pdf     4  o  Copilot Chat, a Microsoft Generative AI cha...
# 6      Cambridge.pdf     5  •  City of Cambridge Written Information Secur...
# 7      Cambridge.pdf     6  o  Test results, diagnoses, or treatment detai...
# 8      Cambridge.pdf     7  used in limited non-sensitive, low-risk \ncirc...
# 9      LongBeach.pdf     1  Generative AI Guidance \n\nV 1.3 \n\nIntroduct...
# 10     LongBeach.pdf     2  City of Long Beach Generative AI Guidance v1.3...
# 11     LongBeach.pdf     3  City of Long Beach Generative AI Guidance v1.3...
# 12     LongBeach.pdf     4  City of Long Beach Generative AI Guidance v1.3...
# 13     LongBeach.pdf     5  City of Long Beach Generative AI Guidance v1.3...
# 14     LongBeach.pdf     6  City of Long Beach Generative AI Guidance v1.3...
# 15     LongBeach.pdf     7  City of Long Beach Generative AI Guidance v1.3...
# 16     LongBeach.pdf     8  City of Long Beach Generative AI Guidance v1.3...
# 17     LongBeach.pdf     9  City of Long Beach Generative AI Guidance v1.3...
# 18     LongBeach.pdf    10  City of Long Beach Generative AI Guidance v1.3...
# 19       SanJose.pdf     1  City of San José \nArtificial Intelligence (AI...
# 20       SanJose.pdf     2  City of San José \nArtificial Intelligence (AI...
# 21       SanJose.pdf     3  City of San José \nArtificial Intelligence (AI...
# 22       SanJose.pdf     4  City of San José \nArtificial Intelligence (AI...
# 23            SF.pdf     1  San Francisco Generative AI Guidelines (2025) ...
# 24            SF.pdf     2  1.1. Purpose of the Guidelines \n\nThese guide...
# 25            SF.pdf     3  As a general rule, City employees must always ...
# 26            SF.pdf     4  For these use-cases, AI can serve as a support...
# 27            SF.pdf     5  Example: Quoting AI-Generated Text \n\nWhen as...
# 28            SF.pdf     6  o  Charter Section 16.130, Privacy First Polic...
# 29            SF.pdf     7  o  Notifying DT of any updates if GenAI tools ...
# 30            SF.pdf     8  5. Background \n\n5.1. Current Legislative and...
# 31            SF.pdf     9  This report includes content drafted with supp...
# 32            SF.pdf    10  political and other biases. Since the models h...
# 33            DC.pdf     1  District of Columbia Government – Office of th...
# 34            DC.pdf     2  4.1.7. \n\nPrior to using any AI and ML platfo...
# 35            DC.pdf     3  6.  Definitions \n\nThe definition of the term...
# 36            DC.pdf     4  APPENDIX \n\nAppendix 1 – Terms and Definition...
# 37         Tempe.pdf     1  Ethical Artificial Intelligence (AI) Policy\n\...
# 38         Tempe.pdf     2  steps to prevent discrimination, protect priva...
# 39         Tempe.pdf     3  IV.\n\nAI Governance\n\n1. Departments shall\n...
# 40        Boston.pdf     1  City of Boston Interim Guidelines\nfor Using G...
# 41        Boston.pdf     2  Sample Use Cases\n\nThese are some of the type...
# 42        Boston.pdf     3  get the beneﬁts from the tools while avoiding ...
# 43        Boston.pdf     4  Guidelines\n\nFact Check and review all conten...
# 44        Boston.pdf     5  AI, contact DoIT so we can help you provision ...
# 45        Boston.pdf     6  3. Do not use generative AI to create communic...
# 46        Boston.pdf     7  Do’s:\n\n1. Try different languages. ChatGPT, ...
# 47        Boston.pdf     8  3. Be aware that the resulting summary might h...
# 48        Boston.pdf     9  ● Example: make an image in a medieval style o...
# 49        Boston.pdf    10  discuss important questions about the impact o...
# 50       Lebanon.pdf     1  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 51       Lebanon.pdf     2  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 52       Lebanon.pdf     3  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 53       Lebanon.pdf     4  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 54       Lebanon.pdf     5  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 55       Lebanon.pdf     6  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 56       Lebanon.pdf     7  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
#
#                                          cleaned_text
# 0   purpose this article provides guidance regardi...
# 1   stereotypes users must edit or disregard biase...
# 2   intelligence ai information technology departm...
# 3   only use city approved authorized ai tools for...
# 4   recommended practice to improve team learning ...
# 5   copilot chat microsoft generative ai chatbot i...
# 6   city of cambridge written information security...
# 7   test results diagnoses or treatment details pr...
# 8   used in limited non sensitive low risk circums...
# 9   generative ai guidance\n\nintroduction\n\ngene...
# 10  approved gen ai systems\n\nsystems the city of...
# 11  sample language to request external collaborat...
# 12  any information that if exposed publicly would...
# 13  one chat will not impact your next one to do t...
# 14  department specific guidance\n\ncity departmen...
# 15  recommended trainings and resources\n\ntrainin...
# 16  serves as community of practice for government...
# 17  transparency accountability\n\nwe acknowledge ...
# 18  language and other types of content to perform...
# 19  purpose\n\nthis policy establishes governance ...
# 20  effectively managed with the intention of redu...
# 21  prohibited uses\n\nthe use of certain ai syste...
# 22  subject to disciplinary action up to and inclu...
# 23  for all city and county personnel including em...
# 24  purpose of the guidelines\n\nthese guidelines ...
# 25  as general rule city employees must always tho...
# 26  for these use cases ai can serve as support to...
# 27  example quoting ai generated text\n\nwhen aske...
# 28  charter section privacy first policy administr...
# 29  notifying dt of any updates if gen ai tools ar...
# 30  background\n\ncurrent legislative and regulato...
# 31  this report includes content drafted with supp...
# 32  political and other biases since the models ha...
# 33  approval date review by legal counsel\n\ntbd\n...
# 34  prior to using any ai and ml platforms cyber a...
# 35  definitions\n\nthe definition of the terms use...
# 36  appendix\n\nappendix terms and definitions\n\n...
# 37  purpose the city of tempe established the ethi...
# 38  steps to prevent discrimination protect privac...
# 39  ai governance\n\ndepartments shall\n\ndefine c...
# 40  city of boston interim guidelines for using ge...
# 41  these are some of the types of uses that could...
# 42  get the benefits from the tools while avoiding...
# 43  guidelines\n\nfact check and review all conten...
# 44  ai contact do it so we can help you provision ...
# 45  do not use generative ai to create communicati...
# 46  do\n\ntry different languages chat gpt bard an...
# 47  be aware that the resulting summary might have...
# 48  example make an image in medieval style of res...
# 49  discuss important questions about the impact o...
# 50  page of\n\nsection purpose\n\nproviding framew...
# 51  page of\n\ncode and emails chat gpt chat gpt a...
# 52  page of\n\nsocial media without any human over...
# 53  page of\n\neducation and awareness management ...
# 54  page of\n\nthe appropriate amount of human ove...
# 55  page of\n\npolicy enforcement non compliance w...
# 56  page of\n\nsection policy procedure revision h...

# %%
# let's now explode by double newlines to get paragraphs
df_exploded = df.assign(
    cleaned_text = df['cleaned_text'].str.split('\n\n')
).explode('cleaned_text').reset_index(drop=True)

# %%
df_exploded
# Out:
#              document  page  \
# 0    SaltLakeCity.pdf     1
# 1    SaltLakeCity.pdf     1
# 2    SaltLakeCity.pdf     1
# 3    SaltLakeCity.pdf     1
# 4    SaltLakeCity.pdf     1
# ..                ...   ...
# 872       Lebanon.pdf     7
# 873       Lebanon.pdf     7
# 874       Lebanon.pdf     7
# 875       Lebanon.pdf     7
# 876       Lebanon.pdf     7
#
#                                                   text  \
# 0    ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# 1    ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# 2    ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# 3    ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# 4    ARTICLE E. USE OF GENERATIVE ARTIFICIAL INTELL...
# ..                                                 ...
# 872  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 873  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 874  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 875  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
# 876  ADMINISTRATIVE POLICIES &  PROCEDURES\n\nUse o...
#
#                                           cleaned_text
# 0    purpose this article provides guidance regardi...
# 1    definitions artificial intelligence ai machine...
# 2    artificial intelligence system any system soft...
# 3    compliant artificial intelligence platform gen...
# 4    generative artificial intelligence branch of a...
# ..                                                 ...
# 872          section policy procedure revision history
# 873                                            section
# 874                                          revisions
# 875                                               date
# 876    original adoption amendment amendment amendment
#
# [877 rows x 4 columns]

# %%
# count paragraphs per document
df_exploded['document'].value_counts()
# Out:
# document
# SF.pdf              148
# Boston.pdf          145
# LongBeach.pdf       141
# Cambridge.pdf       108
# DC.pdf              102
# Lebanon.pdf          81
# SanJose.pdf          75
# Tempe.pdf            46
# SaltLakeCity.pdf     31
# Name: count, dtype: int64

# %%
# export as csv 
df_exploded.to_csv('../data/processed/pdf_paragraphs.csv', index=False)
